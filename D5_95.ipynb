# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pd.set_option("display.max_columns", None)

# %%
df=pd.read_csv('/content/gdrive/MyDrive/Kik-Net Data/attributes_fixed.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5,10,24,29,33,47,48,66,81,82,123,124) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1=df[(df['MT_Magnitude_']>= 3.5) & (df['MT_Magnitude_'] <= 7)&(df['rjb_0'] >=30) &(df['rjb_0'] <=300)&(df['Tectonic_Garcia_'] ==1)]

# %%
from scipy import stats
df1['d5_75_new'] = stats.gmean(df1.loc[:,['D5_75_EW2','D5_75_NS2']], axis=1)
df1['d5_95_new']=stats.gmean(df1.loc[:,['D5_95_EW2','D5_95_NS2']], axis=1)
df1['d20_80_new']=stats.gmean(df1.loc[:,['D20_80_EW2','D20_80_NS2']], axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df1.head()
# Out:
#        X              Code                                Adress  Vs30  Z1  \
# 117  117  GNMH069803170803  ['/19980317080300/GNMH069803170803']   NaN NaN
# 118  118  IBRH089803170803  ['/19980317080300/IBRH089803170803']   NaN NaN
# 119  119  NIGH019803170803  ['/19980317080300/NIGH019803170803']   NaN NaN
# 121  121  IBRH089803231837  ['/19980323183700/IBRH089803231837']   NaN NaN
# 122  122  NIGH019803231837  ['/19980323183700/NIGH019803231837']   NaN NaN
#
#     ry_literature  MT_Magnitude_      rrup_0    repi_1_std       rjb_0  \
# 117           NaN            4.6  182.024225  2.840000e-14  175.643899
# 118           NaN            4.6  127.899132  4.260000e-14  118.072329
# 119           NaN            4.6  219.521708  8.530000e-14  214.523557
# 121           NaN            5.4   73.551585  1.420000e-14   60.536219
# 122           NaN            5.4  237.144873  5.680000e-14  234.147484
#
#     ry0_literature       ry0_1      repi_1  depth   rhypo_0_std  \
# 117            NaN  156.558009  176.303372     51  2.840000e-14
# 118            NaN  118.107596  118.899903     51  2.840000e-14
# 119            NaN   77.549788  214.772593     51  2.840000e-14
# 121            NaN   55.932584   61.654301     45  1.420000e-14
# 122            NaN  183.691910  234.917470     45  0.000000e+00
#
#      Focal_mechanism_kegan_  rjb_0_std   T_0_std      Origin_Time_  \
# 117                     1.0   0.311570  0.246650  [b'08:03:37.31']
# 118                     1.0   0.333678  0.245803  [b'08:03:37.31']
# 119                     1.0   0.251701  0.244665  [b'08:03:37.31']
# 121                     1.0   0.506288  0.075195  [b'18:37:09.34']
# 122                     1.0   0.452980  0.074056  [b'18:37:09.34']
#
#     lastCorrectionDate  ry_1_std     Longitude_       Unit_  \
# 117          3/17/1998  0.325417  [b'141.2613']  [b'1e+15']
# 118          3/16/1998  0.327219  [b'141.2613']  [b'1e+15']
# 119          3/17/1998  0.322960  [b'141.2613']  [b'1e+15']
# 121          3/16/1998  1.036639  [b'141.1750']  [b'1e+17']
# 122          3/23/1998  1.016977  [b'141.1750']  [b'1e+17']
#
#                   Region_Name_ rhypo_literature        ry_1  samplingFreq  \
# 117  [b'E_OFF_FUKUSHIMA_PREF']              NaN  157.250174           200
# 118  [b'E_OFF_FUKUSHIMA_PREF']              NaN  118.799760           200
# 119  [b'E_OFF_FUKUSHIMA_PREF']              NaN   78.241953           200
# 121    [b'E_OFF_IBARAKI_PREF']              NaN   58.097210           200
# 122    [b'E_OFF_IBARAKI_PREF']              NaN  185.856535           200
#
#         rhypo_1  rjb_1_std T_literature         U_0     lat   T_1_std  \
# 117  183.660040   0.410882          NaN -153.686180  37.036  0.599001
# 118  129.566106   0.359917          NaN -118.169326  37.036  0.596780
# 119  220.866668   0.548947          NaN  -70.557501  37.036  0.594417
# 121   76.329884   1.158403          NaN  -30.351048  36.370  1.411208
# 122  239.197121   1.190014          NaN  103.982027  36.370  1.414015
#
#     U_literature        rx_0       rjb_1 MT_Depth_  ry_0_std originDate  \
# 117          NaN  -84.579616  175.524271   [b'50']  0.304122  3/17/1998
# 118          NaN    0.725821  118.045854   [b'50']  0.305721  3/17/1998
# 119          NaN -202.095562  214.243401   [b'50']  0.301939  3/17/1998
# 121          NaN  -52.264601   58.872778   [b'35']  0.957687  3/23/1998
# 122          NaN -211.507035  232.329213   [b'35']  0.955809  3/23/1998
#
#      Tectonic_Garcia_        rx_1    repi_0_std    Var_Red_  rrup_1_std  \
# 117               1.0   80.917784  2.840000e-14  [b'94.59']    0.356592
# 118               1.0   -3.106208  4.260000e-14  [b'94.59']    0.344641
# 119               1.0  201.242636  8.530000e-14  [b'94.59']    0.481772
# 121               1.0  -18.092374  1.420000e-14  [b'83.07']    1.039733
# 122               1.0  146.470828  5.680000e-14  [b'83.07']    1.119993
#
#           ry0_0  JMA_Depth_   rhypo_1_std rx_literature name_literature  \
# 117  153.686180  [b'51.44']  2.840000e-14           NaN             NaN
# 118  118.169326  [b'51.44']  2.840000e-14           NaN             NaN
# 119   70.557501  [b'51.44']  2.840000e-14           NaN             NaN
# 121   30.351048  [b'44.96']  1.420000e-14           NaN             NaN
# 122   99.773372  [b'44.96']  0.000000e+00           NaN             NaN
#
#          repi_0      Strike_  Ztor_1_std        ry_0  rx_1_std recordDate  \
# 117  176.303372  [b'32;214']   50.949500 -154.377927  0.599001  3/17/1998
# 118  118.899903  [b'32;214']   50.949500 -118.861073  0.596780  3/17/1998
# 119  214.772593  [b'32;214']   50.949500  -71.249248  0.594417  3/17/1998
# 121   61.654301   [b'5;263']   44.170806  -32.455375  1.411208  3/23/1998
# 122  234.917470   [b'5;263']   44.170806  101.877699  1.414015  3/23/1998
#
#      rx_0_std  ry0_1_std  stationLon     rhypo_0      lon         T_0  \
# 117  0.246650   0.357888    139.5443  183.660040  141.264  -84.579616
# 118  0.245803   0.359291    140.5621  129.566106  141.264    0.725821
# 119  0.244665   0.355997    138.8876  220.866668  141.264 -202.095562
# 121  0.075195   1.116900    140.5621   76.329884  141.180  -52.264601
# 122  0.074056   1.101481    138.8876  239.197121  141.180 -211.507035
#
#      originTime Number_of_Stations_            Mo_  rrup_0_std  Ztor_0_std  \
# 117  08:03:00\n              [b'3']  [b'8.25e+15']    0.382838   50.211738
# 118  08:03:00\n              [b'3']  [b'8.25e+15']    0.376394   50.211738
# 119  08:03:00\n              [b'3']  [b'8.25e+15']    0.363153   50.211738
# 121  18:37:00\n              [b'3']  [b'1.28e+17']    0.953443   41.989511
# 122  18:37:00\n              [b'3']  [b'1.28e+17']    0.531107   41.989511
#
#     repi_literature  scaleFactor        Dip_  direction JMA_Magnitude_  \
# 117             NaN     0.000238  [b'68;22']          2       [b'4.5']
# 118             NaN     0.000238  [b'68;22']          2       [b'4.5']
# 119             NaN     0.000238  [b'68;22']          2       [b'4.5']
# 121             NaN     0.000238  [b'87;16']          2       [b'5.3']
# 122             NaN     0.000238  [b'87;16']          2       [b'5.3']
#
#         Ztor_0     Ztor_1  stationLat Focal_mechanism_Garcia_        Rake_  \
# 117  50.211738  50.949500     36.2441                  [b'1']   [b'89;92']
# 118  50.211738  50.949500     36.1188                  [b'1']   [b'89;92']
# 119  50.211738  50.949500     37.4272                  [b'1']   [b'89;92']
# 121  41.989511  44.170806     36.1188                  [b'0']  [b'75;167']
# 122  41.989511  44.170806     37.4272                  [b'0']  [b'75;167']
#
#      durationTime         T_1   U_1_std         U_1  ry0_0_std rjb_literature  \
# 117            60   80.917784  0.344639  157.942339   0.332184            NaN
# 118            76   -3.106208  0.346585  119.491925   0.333930            NaN
# 119            60  201.242636  0.341964   78.934118   0.329795            NaN
# 121           114  -18.092374  1.109636   60.261835   1.009370            NaN
# 122           118  146.470828  1.088458  188.021161   1.051880            NaN
#
#     Ztor_literature Tectonic_Zhoa_      rrup_1     Latitude_  mag   U_0_std  \
# 117             NaN         [b'1']  182.316614  [b'37.0288']  4.5  0.332184
# 118             NaN         [b'1']  128.148157  [b'37.0288']  4.5  0.333930
# 119             NaN         [b'1']  219.580201  [b'37.0288']  4.5  0.329795
# 121             NaN         [b'1']   73.468577  [b'36.3700']  5.3  1.009370
# 122             NaN         [b'1']  235.949059  [b'36.3700']  5.3  1.007396
#
#          Origin_day_  rrup_literature  magnitude_literature   snr_EW1  \
# 117  [b'1998/03/17']              NaN                   NaN  0.984589
# 118  [b'1998/03/17']              NaN                   NaN  0.427142
# 119  [b'1998/03/17']              NaN                   NaN  0.363423
# 121  [b'1998/03/23']              NaN                   NaN  0.955049
# 122  [b'1998/03/23']              NaN                   NaN  0.204217
#
#       snr_NS1   snr_EW2   snr_NS2  fLow_EW1  fLow_NS1  fLow_EW2  fLow_NS2  \
# 117  0.984589  0.821905  0.821905  0.050000  0.050000  0.137329  0.137329
# 118  0.427142  0.972535  0.972535  0.100000  0.100000  0.050000  0.050000
# 119  0.363423  0.534194  0.534194  0.100000  0.100000  0.100000  0.100000
dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
input_var=df2[['MT_Magnitude_','rrup_0']]

input_var.head()
# Out:
#      MT_Magnitude_      rrup_0
# 242            4.3  201.327851
# 243            4.3  267.443533
# 244            4.3  147.362858
# 245            4.3  137.572160
# 246            4.3  135.336606

# %%
y_var=df2[['d5_95_new']]
y_var=np.log(y_var)
y_var=np.array(y_var)
y_var
# Out:
# array([[3.14721101],
#        [2.50122469],
#        [2.50386236],
#        ...,
#        [3.27600959],
#        [3.49615445],
#        [3.16737019]])

# %%
import sklearn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(input_var,y_var,test_size=0.3, random_state=21)

# %%
X_train=preprocessing.scale(X_train)
X_test=preprocessing.scale(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import keras.models
from keras.models import Sequential
from keras.layers import Dense

# %%
tf.random.set_seed(55)

# %%
model=Sequential([Dense(units=5, input_shape=(2,), activation='relu'),
                  Dense(units=1, activation='linear')
                 ])

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import RMSprop

# %%
model.compile(optimizer=Adam(learning_rate=0.01),loss='mean_squared_error')

# %%
history=model.fit(X_train, y_train,batch_size=64, epochs=20, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/20
# 577/577 [==============================] - 14s 2ms/step - loss: 8.4262 - val_loss: 4.0583
# Epoch 2/20
# 577/577 [==============================] - 1s 1ms/step - loss: 3.0787 - val_loss: 1.1210
# Epoch 3/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.8672 - val_loss: 0.5131
# Epoch 4/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.4528 - val_loss: 0.3400
# Epoch 5/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.3118 - val_loss: 0.2427
# Epoch 6/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.2269 - val_loss: 0.1890
# Epoch 7/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1864 - val_loss: 0.1633
# Epoch 8/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1597 - val_loss: 0.1505
# Epoch 9/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1478 - val_loss: 0.1429
# Epoch 10/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1412 - val_loss: 0.1383
# Epoch 11/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1396 - val_loss: 0.1361
# Epoch 12/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1349 - val_loss: 0.1349
# Epoch 13/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1356 - val_loss: 0.1340
# Epoch 14/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1309 - val_loss: 0.1332
# Epoch 15/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1309 - val_loss: 0.1326
# Epoch 16/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1335 - val_loss: 0.1321
# Epoch 17/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1308 - val_loss: 0.1320
# Epoch 18/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1320 - val_loss: 0.1317
# Epoch 19/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1323 - val_loss: 0.1316
# Epoch 20/20
# 577/577 [==============================] - 1s 1ms/step - loss: 0.1312 - val_loss: 0.1311

# %%
history_dict=history.history
    
loss_values= history_dict['loss']
val_loss_values=history_dict['val_loss']
plt.figure()
    
plt.plot(loss_values, 'black', label='training loss')
plt.plot(val_loss_values, 'red', label='val training loss')
plt.legend(fontsize=12)
plt.xlabel('No of epochs')
plt.ylabel('Loss')
plt.text(7.5,6.2, '$D_{5-95}$', fontsize=15)
plt.show()

# %%
y_test_pred=model.predict(X_test)
error=y_test_pred-y_test
plt.hist(error, bins=25, color='black')
plt.xlabel('Prediction error')
plt.ylabel('count')
plt.text(2,4000, '$D_{5-95}$', fontsize=15)
# Out:
# Text(2, 4000, '$D_{5-95}$')
